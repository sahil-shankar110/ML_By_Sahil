# %% [markdown]
# <a href="https://colab.research.google.com/github/sahil-shankar110/localRepo/blob/main/First_ML_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
placement = pd.read_csv("/content/placement.csv")

# %%
placement.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %% [markdown]
# # Data Preprocessing
# **1-Checking --> Null Values**
#
# **2-Removed Column named --> Unnamed**

# %%
placement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
placement = placement.iloc[:,1:]

# %% [markdown]
# # EDA

# %%
plt.scatter(placement["cgpa"] , placement["iq"],c=placement["placement"])
plt.legend()
# Out:
# /tmp/ipython-input-196309830.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Extract Input and Output Columns

# %%
x = placement.iloc[:,0:2]
y = placement.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %% [markdown]
# # Train_test_split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 1    5.9  106.0
# 68   4.0   75.0
# 88   4.4  149.0
# 90   7.3   86.0
# 12   5.4  139.0
# ..   ...    ...
# 91   7.5  158.0
# 50   3.5  233.0
# 59   4.8  112.0
# 13   6.4  116.0
# 55   7.8  114.0
#
# [90 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['cgpa'].plot(kind='hist', bins=20, title='cgpa')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['iq'].plot(kind='hist', bins=20, title='iq')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# ...

# %%
y_train
# Out:
# 1     0
# 68    0
# 88    0
# 90    1
# 12    0
#      ..
# 91    1
# 50    0
# 59    0
# 13    1
# 55    1
# Name: placement, Length: 90, dtype: int64

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.91393507, -1.55641454],
#        [ 0.89101507, -1.48205037],
#        [ 1.14886509, -0.93671312],
#        [-0.65608505, -0.8375609 ],
#        [ 0.97696508,  0.67451057],
#        [ 0.37531503,  0.42663   ],
#        [ 1.40671511, -0.86234895],
#        [-0.91393507,  0.2531136 ],
#        [-0.99988508, -0.29222365],
#        [-0.91393507, -0.09391919],
#        [ 0.031515  , -1.43247426],
#        [-0.99988508,  0.97196725],
#        [-1.34368511,  0.62493445],
#        [ 0.031515  , -0.54010422],
#        [ 2.18026517, -0.09391919],
#        [-1.08583508, -1.77950706],
#        [ 0.63316505,  0.74887474],
#        [ 0.28936502,  0.10438526],
#        [ 0.71911506,  0.42663   ],
#        [-0.91393507,  1.78997312],
#        [-0.65608505,  0.92239114],
#        [ 1.3207651 ,  0.15396138],
#        [ 1.3207651 , -1.55641454],
#        [ 0.71911506, -0.29222365],
#        [-0.22633502,  0.40184194],
#        [ 0.28936502,  0.0795972 ],
#        [ 0.54721504,  0.35226583],
# ...

# %%
x_test = scalar.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.28936502, -0.51531616],
#        [ 1.40671511,  0.10438526],
#        [-0.99988508,  0.42663   ],
#        [ 0.71911506, -0.01955502],
#        [ 0.89101507,  1.26942393],
#        [ 0.80506506,  0.35226583],
#        [-0.82798506, -0.81277284],
#        [ 0.031515  , -1.95302345],
#        [ 0.031515  ,  0.62493445],
#        [ 0.031515  ,  0.00523303]])

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Evaluating Model

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 98    1
# 30    1
# 51    0
# 0     1
# 52    1
# 11    1
# 25    0
# 10    1
# 33    0
# 27    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open("model.pkl","wb"))
